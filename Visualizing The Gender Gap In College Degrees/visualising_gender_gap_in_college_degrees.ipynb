# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# %%
women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

# %% [markdown]
# ## Comparing STEM categories

# %%
fig = plt.figure(figsize=(18,3))
for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], color=cb_dark_blue, lw=3, label='Women')
    ax.plot(women_degrees['Year'], 100- women_degrees[stem_cats[sp]], color=cb_orange, lw=3, label='Men')
    # Set axis limits
    ax.set_xlim(1968,2011)
    ax.set_ylim(0,100)
    # Remove tick-markers
    ax.tick_params(left=False, right=False, top=False, bottom=False)
    # Remove/hide spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set plot label
    ax.set_label(stem_cats[sp])
    
# Add text annotation - left chart
left_ax = fig.axes[0]
left_ax.text(x=2005, y=87, s='Men')
left_ax.text(x=2002, y=8, s='Women')

# Add text annotation - right chart
right_ax = fig.axes[-1]
right_ax.text(x=2005, y=62, s='Men')
right_ax.text(x=2002, y=35, s='Women')

# %% [markdown]
# ## Comparing across all degree categories

# %%
fig = plt.figure(figsize=(16,20))

# First column of grid(6x3) : STEM cats
for i,sp in enumerate(range(0,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(stem_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0: # If first subplot of STEM column
        ax.text(2004, 83, 'Women')
        ax.text(2006, 13, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 88, 'Men')
        ax.text(2005, 8, 'Women')

# Second column of the grid(6x3) : lib_arts_cats (last subplot of this column will be empty)
for i,sp in enumerate(range(1,15,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(lib_arts_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0: # If first subplot in the column
        ax.text(2005, 75, 'Women')
        ax.text(2006, 21, 'Men')

# Third and last column of grid(6x3) : Other cats
for i,sp in enumerate(range(2,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(other_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off")
    
    if i == 0: # If first subplot of STEM column
        ax.text(2005, 90, 'Women')
        ax.text(2006, 5, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 62, 'Men')
        ax.text(2004, 33, 'Women')

# %% [markdown]
# ## Hiding x-axis labels

# %%
fig = plt.figure(figsize=(16,20))

# First column of grid(6x3) : STEM cats
for i,sp in enumerate(range(0,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(stem_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2004, 83, 'Women')
        ax.text(2006, 13, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 88, 'Men')
        ax.text(2005, 8, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Second column of the grid(6x3) : lib_arts_cats (last subplot of this column will be empty)
for i,sp in enumerate(range(1,15,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(lib_arts_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot in the column
        ax.text(2005, 75, 'Women')
        ax.text(2006, 21, 'Men')
    if i==4:
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Third and last column of grid(6x3) : Other cats
for i,sp in enumerate(range(2,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # Set plot title
    ax.set_title(other_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2005, 90, 'Women')
        ax.text(2006, 5, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 62, 'Men')
        ax.text(2004, 33, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# %% [markdown]
# ## Setting y-axis labels

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))

# First column of grid(6x3) : STEM cats
for i,sp in enumerate(range(0,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Set plot title
    ax.set_title(stem_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2004, 83, 'Women')
        ax.text(2006, 13, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 88, 'Men')
        ax.text(2005, 8, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Second column of the grid(6x3) : lib_arts_cats (last subplot of this column will be empty)
for i,sp in enumerate(range(1,15,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Set plot title
    ax.set_title(lib_arts_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot in the column
        ax.text(2005, 75, 'Women')
        ax.text(2006, 21, 'Men')
    if i==4:
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Third and last column of grid(6x3) : Other cats
for i,sp in enumerate(range(2,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Set plot title
    ax.set_title(other_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2005, 90, 'Women')
        ax.text(2006, 5, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 62, 'Men')
        ax.text(2004, 33, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# %% [markdown]
# ## Adding a horizontal line

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
cb_gray = (171/255, 171/255, 171/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))

# First column of grid(6x3) : STEM cats
for i,sp in enumerate(range(0,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(stem_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2004, 83, 'Women')
        ax.text(2006, 13, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 88, 'Men')
        ax.text(2005, 8, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Second column of the grid(6x3) : lib_arts_cats (last subplot of this column will be empty)
for i,sp in enumerate(range(1,15,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(lib_arts_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot in the column
        ax.text(2005, 75, 'Women')
        ax.text(2006, 21, 'Men')
    if i==4:
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Third and last column of grid(6x3) : Other cats
for i,sp in enumerate(range(2,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(other_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2005, 90, 'Women')
        ax.text(2006, 5, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 62, 'Men')
        ax.text(2004, 33, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# %% [markdown]
# ## Exporting to a file

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
cb_gray = (171/255, 171/255, 171/255)
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']
fig = plt.figure(figsize=(16,20))

# First column of grid(6x3) : STEM cats
for i,sp in enumerate(range(0,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(stem_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2004, 83, 'Women')
        ax.text(2006, 13, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 88, 'Men')
        ax.text(2005, 8, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Second column of the grid(6x3) : lib_arts_cats (last subplot of this column will be empty)
for i,sp in enumerate(range(1,15,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(lib_arts_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot in the column
        ax.text(2005, 75, 'Women')
        ax.text(2006, 21, 'Men')
    if i==4:
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')

# Third and last column of grid(6x3) : Other cats
for i,sp in enumerate(range(2,18,3)):
    # Add subplot
    ax = fig.add_subplot(6,3,sp+1)
    # Plot the lines
    ax.plot(women_degrees['Year'], women_degrees[other_cats[i]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[i]], c=cb_orange, label='Men', linewidth=3)
    # Hide the spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    # Set x & y axis limits
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    # set y-ticks
    ax.set_yticks([0,100])
    # Adding a horizontal line midway through 0 to 100.
    ax.axhline(50, c= cb_gray, alpha=0.3)
    # Set plot title
    ax.set_title(other_cats[i])
    # Hide tick-markers on all axis of plot.
    ax.tick_params(bottom="off", top="off", left="off", right="off", labelbottom='off')
    
    if i == 0: # If first subplot of STEM column
        ax.text(2005, 90, 'Women')
        ax.text(2006, 5, 'Men')
    elif i == 5: # If last subplot of STEM column
        ax.text(2006, 62, 'Men')
        ax.text(2004, 33, 'Women')
        # Turn on the labelbottom of the last subplot of the current column
        ax.tick_params(labelbottom='on')
# Export to a file before calling pyplot.show()
fig.savefig("gender_degrees.png")

# %% [markdown]
# ## Done.
